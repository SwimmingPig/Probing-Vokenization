# %%
import h5py
from numpy import array

# %%
filename = "./contextual-repr-analysis/contextualizers/bert_base_cased/ewt_pos.hdf5"

with h5py.File(filename, "r") as f:
    # List all groups
    # print("Keys: %s" % f.keys())
    print(len(f.keys()))
    a_group_key = list(f.keys())[0]

    # Get the data
    data = list(f[a_group_key])
    print(data)
# Out:
# 15524
# [array([[-1.237479,  0.633781,  0.929692, ...,  0.289505,  0.005948,
#          0.681285],
#        [-1.328466,  0.774279,  0.276522, ...,  0.277268, -0.544577,
#          0.654504],
#        [ 0.74208 , -1.20471 , -1.396911, ..., -0.807354,  0.354909,
#         -1.97868 ],
#        ...,
#        [ 0.35456 , -0.976216, -0.032431, ...,  0.835373,  0.184326,
#          1.315494],
#        [ 0.317734,  0.195854, -0.292996, ...,  0.051467,  1.084055,
#          0.324701],
#        [-0.507484,  0.640852,  0.944141, ...,  0.318465,  0.358424,
#          0.122282]], dtype=float32), array([[-0.956778,  0.296848,  0.931557, ..., -0.044322,  0.039722,
#          0.90007 ],
#        [-1.358075,  0.916364, -0.072927, ..., -0.120086, -0.752562,
#          0.66303 ],
#        [ 0.536027, -1.006974, -1.039093, ..., -1.494841,  0.243032,
#         -2.419356],
#        ...,
#        [ 0.415973, -0.713941, -0.007601, ...,  0.410682, -0.194226,
#          1.622569],
# ...
